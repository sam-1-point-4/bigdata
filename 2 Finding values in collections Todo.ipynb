# %%
import random
random.seed(1000)
import matplotlib.pyplot as plt

# %% [markdown]
# # Create Data

# %%
# number of elements in list
n = 50

# list of unsorted items
items = [int(random.random()*n) for _ in range(n)]

# value to be searched in list
value = int(random.random()*n)

# sorted list 
sorted_items = sorted(items)

# %% [markdown]
# # Find Value in Unsorted List with Linear Search
#
# Animation: https://yongdanielliang.github.io/animation/web/LinearSearchNew.html

# %%
def get_item(items, index):
    """value of of an item in a list based on the index of the value
        args:
            - items: List of items
            - index: index of the requested item
        return:
            - value of the requested item
    """
    if index == -1:
        print("Not in the list")
        return None
    else:
        return items[index]

# %%
def find_element(items, value):
    """Linear search for a value in a list of items
        args:
            - items: unsorted list of items
            - value: searched value
        return:
            - index of value or -1 if not in list
    """
    for item, value in enumerate (items):
        if item == value:
            return item
    return -1

# %%
index = find_element(items, value)
print(index)
# Out:
# 20

# %%
print(value)
get_item(items, index)
# Out:
# 14
# 20

# %% [markdown]
# ### Question:
# * Time your function with differently sized inputs by
# * searching for each input size for a non-existing element
# * and plot the change of the time to the size of the input
#
# (see 1 Timing Algorithms)

# %%
import time

# List of input sizes
input_sizes = [50, 100, 200, 500, 1000, 2000, 5000]
times = []

# Measure the time for each input size
for n in input_sizes:
    items = [int(random.random() * n) for _ in range(n)]
    value = n + 1  # Non-existing element
    start_time = time.time()
    find_element(items, value)  # Linear search
    end_time = time.time()
    times.append(end_time - start_time)

# Plot the results
plt.plot(input_sizes, times, marker='o')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Time Complexity of Linear Search')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Question: What is the time complexity of searching for a value in an unsorted list?
#
# Big O Notation

# %% [markdown]
# TODO: The time complexity of searching for a value in an unsorted list using linear search is **O(n)**, where `n` is the number of elements in the list. This is because, in the worst case, the algorithm may need to check every element in the list to find the target or determine its absence.
# as

# %% [markdown]
# # Find Value in Sorted list with Binary Search

# %% [markdown]
# Animation: https://yongdanielliang.github.io/animation/web/BinarySearchNew.html

# %%
def find_sorted(items, value):
    """Binary search for a value in a list of sorted items
        args:
            - items: sorted list of items
            - value: searched value
        return:
            - index of value or -1 if not in list
    """
    low, high = 0, len(items) - 1
    while low <= high:
        mid = (low + high) // 2
        if items[mid] == value:
            return mid
        elif items[mid] < value:
            low = mid + 1
        else:
            high = mid - 1
    return -1

# %%
# a value that is not in the list so that we get the worst case time
value = n+1 
find_sorted(sorted_items, value)
# Out:
# -1

# %%
n = 100
items = [int(random.random()*n) for _ in range(n)]
value = n+1 
find_sorted(sorted_items, value)
# Out:
# -1

# %%
n = 200
items = [int(random.random()*n) for _ in range(n)]
value = n+1 
find_sorted(sorted_items, value)
# Out:
# -1

# %% [markdown]
# ### Question:
# * Time your function with differently sized inputs by
# * searching for each input size for a non-existing element
# * and plot the change of the time to the size of the input
#
# (see 1 Timing Algorithms)

# %%
# List of input sizes
input_sizes = [50, 100, 200, 500, 1000, 2000, 5000]
times = []

# Measure the time for each input size
for n in input_sizes:
    sorted_items = sorted([int(random.random() * n) for _ in range(n)])
    value = n + 1  # Non-existing element
    start_time = time.time()
    find_sorted(sorted_items, value)  # Binary search
    end_time = time.time()
    times.append(end_time - start_time)

# Plot the results
plt.plot(input_sizes, times, marker='o')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Time Complexity of Binary Search')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Question: What is the time complexity of binary search?
#
# Big O Notation

# %% [markdown]
# TODO:
# The time complexity of binary search is **O(log n)**, where `n` is the number of elements in the sorted list. This is because the search space is halved with each iteration, leading to a logarithmic growth in the number of steps required to find the target or determine its absence.
